# %% [markdown]
# # Exercise: Generate PPSD
#
# PPSD = Probability Power Spectrum Density

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline 
# %matplotlib widget

# %%
from obspy import read, read_inventory
from obspy.signal import PPSD

from obspy.imaging.cm import pqlx

import glob
import os

# %% [markdown]
# ### Download data using [ObspyDMT](https://github.com/kasra-hosseini/obspyDMT?tab=readme-ov-file#synthetic-seismograms)
#
# Here we are downloading continuous data for one station RR40 and month to generate our PPSD file.

# %%
! obspyDMT --continuous --datapath data_rhum_rum_continuous --min_date 2013-01-01 --max_date 2013-02-01 --sta RR40 --data_source RESIF --net YV --cha BHZ --instrument_correction
# Out:
# --------------------------------------------------------------------------------
# 		   obspyDMT (obspy Data Management Tool)
#
# 	Python Toolbox for Retrieving, Processing and Management of
# 			Large Seismological Datasets
#
# :copyright:
# The ObsPy Development Team (devs@obspy.org)
#
# Developed by Kasra Hosseini
# email: kasra.hosseinizad@earth.ox.ac.uk
#
# :license:
# GNU General Public License, Version 3
# (http://www.gnu.org/licenses/gpl-3.0-standalone.html)
# --------------------------------------------------------------------------------
#
#
# obspyDMT primary mode: continuous
#
#
# =========================================================
# use the local files:
# /Users/mary/Documents/Courses_and_Workshops/IASPEI_Lisbon_SEP'25/codes/data_rhum_rum_continuous/EVENTS-INFO/event_list_pickle
# =========================================================
#
#
# #N  LAT     LON     DEP     DATETIME             MAG     AUTH EV_ID
# --------------------------------------------------------------------------------
# 1   -12345  -12345  -12345  2013-01-01T00:00:00  -12345  NAN  continuous01
# 2   -12345  -12345  -12345  2013-01-02T00:00:00  -12345  NAN  continuous02
# 3   -12345  -12345  -12345  2013-01-03T00:00:00  -12345  NAN  continuous03
# 4   -12345  -12345  -12345  2013-01-04T00:00:00  -12345  NAN  continuous04
# 5   -12345  -12345  -12345  2013-01-05T00:00:00  -12345  NAN  continuous05
# 6   -12345  -12345  -12345  2013-01-06T00:00:00  -12345  NAN  continuous06
# 7   -12345  -12345  -12345  2013-01-07T00:00:00  -12345  NAN  continuous07
# 8   -12345  -12345  -12345  2013-01-08T00:00:00  -12345  NAN  continuous08
# 9   -12345  -12345  -12345  2013-01-09T00:00:00  -12345  NAN  continuous09
# 10  -12345  -12345  -12345  2013-01-10T00:00:00  -12345  NAN  continuous10
# 11  -12345  -12345  -12345  2013-01-11T00:00:00  -12345  NAN  continuous11
# 12  -12345  -12345  -12345  2013-01-12T00:00:00  -12345  NAN  continuous12
# 13  -12345  -12345  -12345  2013-01-13T00:00:00  -12345  NAN  continuous13
# 14  -12345  -12345  -12345  2013-01-14T00:00:00  -12345  NAN  continuous14
# 15  -12345  -12345  -12345  2013-01-15T00:00:00  -12345  NAN  continuous15
# 16  -12345  -12345  -12345  2013-01-16T00:00:00  -12345  NAN  continuous16
# 17  -12345  -12345  -12345  2013-01-17T00:00:00  -12345  NAN  continuous17
# 18  -12345  -12345  -12345  2013-01-18T00:00:00  -12345  NAN  continuous18
# 19  -12345  -12345  -12345  2013-01-19T00:00:00  -12345  NAN  continuous19
# 20  -12345  -12345  -12345  2013-01-20T00:00:00  -12345  NAN  continuous20
# 21  -12345  -12345  -12345  2013-01-21T00:00:00  -12345  NAN  continuous21
# 22  -12345  -12345  -12345  2013-01-22T00:00:00  -12345  NAN  continuous22
# 23  -12345  -12345  -12345  2013-01-23T00:00:00  -12345  NAN  continuous23
# 24  -12345  -12345  -12345  2013-01-24T00:00:00  -12345  NAN  continuous24
# 25  -12345  -12345  -12345  2013-01-25T00:00:00  -12345  NAN  continuous25
# 26  -12345  -12345  -12345  2013-01-26T00:00:00  -12345  NAN  continuous26
# 27  -12345  -12345  -12345  2013-01-27T00:00:00  -12345  NAN  continuous27
# 28  -12345  -12345  -12345  2013-01-28T00:00:00  -12345  NAN  continuous28
# 29  -12345  -12345  -12345  2013-01-29T00:00:00  -12345  NAN  continuous29
# 30  -12345  -12345  -12345  2013-01-30T00:00:00  -12345  NAN  continuous30
# 31  -12345  -12345  -12345  2013-01-31T00:00:00  -12345  NAN  continuous31
# --------------------------------------------------------------------------------
#
# Number of events/intervals: 31
# Time for retrieving and saving the event info: 0:00:00
#
# #Events after filtering: 31
#
# =============
# metadata mode
# =============
# initializing files and directories...DONE
# check the availability: RESIF
#
# availability for event: 1/31 ---> DONE
# Time for checking the availability: 0:00:01.621554
# [INFO] requested data sources:
# RESIF
#
# RESIF -- event: /Users/mary/Documents/Courses_and_Workshops/IASPEI_Lisbon_SEP'25/codes/data_rhum_rum_continuous/continuous01
#
# ========================
# DONE with Event: continuous01
# Time: 0:00:00.001957
# ========================
#
# =============
# metadata mode
# =============
# initializing files and directories...DONE
# check the availability: RESIF
#
# availability for event: 2/31 ---> DONE
# Time for checking the availability: 0:00:01.444521
# [INFO] requested data sources:
# RESIF
#
# RESIF -- event: /Users/mary/Documents/Courses_and_Workshops/IASPEI_Lisbon_SEP'25/codes/data_rhum_rum_continuous/continuous02
#
# ========================
# DONE with Event: continuous02
# Time: 0:00:00.002833
# ========================
#
# =============
# metadata mode
# =============
# initializing files and directories...DONE
# check the availability: RESIF
#
# availability for event: 3/31 ---> DONE
# Time for checking the availability: 0:00:00.916150
# [INFO] requested data sources:
# RESIF
#
# RESIF -- event: /Users/mary/Documents/Courses_and_Workshops/IASPEI_Lisbon_SEP'25/codes/data_rhum_rum_continuous/continuous03
#
# ========================
# DONE with Event: continuous03
# Time: 0:00:00.002421
# ========================
#
# =============
# metadata mode
# =============
# initializing files and directories...DONE
# check the availability: RESIF
#
# availability for event: 4/31 ---> DONE
# Time for checking the availability: 0:00:00.960802
# [INFO] requested data sources:
# RESIF
#
# RESIF -- event: /Users/mary/Documents/Courses_and_Workshops/IASPEI_Lisbon_SEP'25/codes/data_rhum_rum_continuous/continuous04
#
# ========================
# DONE with Event: continuous04
# Time: 0:00:00.001991
# ========================
#
# =============
# metadata mode
# =============
# initializing files and directories...DONE
# check the availability: RESIF
#
# availability for event: 5/31 ---> DONE
# Time for checking the availability: 0:00:00.911154
# [INFO] requested data sources:
# RESIF
#
# RESIF -- event: /Users/mary/Documents/Courses_and_Workshops/IASPEI_Lisbon_SEP'25/codes/data_rhum_rum_continuous/continuous05
#
# ========================
# DONE with Event: continuous05
# Time: 0:00:00.002957
# ========================
#
# =============
# metadata mode
# =============
# initializing files and directories...DONE
# check the availability: RESIF
#
# availability for event: 6/31 ---> DONE
# Time for checking the availability: 0:00:00.966923
# [INFO] requested data sources:
# RESIF
#
# RESIF -- event: /Users/mary/Documents/Courses_and_Workshops/IASPEI_Lisbon_SEP'25/codes/data_rhum_rum_continuous/continuous06
#
# ========================
# DONE with Event: continuous06
# Time: 0:00:00.002727
# ========================
#
# =============
# metadata mode
# =============
# initializing files and directories...DONE
# check the availability: RESIF
#
# availability for event: 7/31 ---> DONE
# Time for checking the availability: 0:00:00.822170
# [INFO] requested data sources:
# RESIF
#
# RESIF -- event: /Users/mary/Documents/Courses_and_Workshops/IASPEI_Lisbon_SEP'25/codes/data_rhum_rum_continuous/continuous07
#
# ========================
# DONE with Event: continuous07
# Time: 0:00:00.003409
# ========================
#
# =============
# metadata mode
# =============
# initializing files and directories...DONE
# check the availability: RESIF
#
# availability for event: 8/31 ---> DONE
# Time for checking the availability: 0:00:00.856631
# [INFO] requested data sources:
# RESIF
#
# RESIF -- event: /Users/mary/Documents/Courses_and_Workshops/IASPEI_Lisbon_SEP'25/codes/data_rhum_rum_continuous/continuous08
#
# ========================
# DONE with Event: continuous08
# Time: 0:00:00.002472
# ========================
#
# =============
# metadata mode
# =============
# initializing files and directories...DONE
# check the availability: RESIF
#
# availability for event: 9/31 ---> DONE
# Time for checking the availability: 0:00:00.865262
# [INFO] requested data sources:
# RESIF
#
# RESIF -- event: /Users/mary/Documents/Courses_and_Workshops/IASPEI_Lisbon_SEP'25/codes/data_rhum_rum_continuous/continuous09
#
# ========================
# DONE with Event: continuous09
# Time: 0:00:00.003071
# ========================
#
# =============
# metadata mode
# =============
# initializing files and directories...DONE
# check the availability: RESIF
#
# availability for event: 10/31 ---> DONE
# Time for checking the availability: 0:00:00.856027
# [INFO] requested data sources:
# RESIF
#
# RESIF -- event: /Users/mary/Documents/Courses_and_Workshops/IASPEI_Lisbon_SEP'25/codes/data_rhum_rum_continuous/continuous10
#
# ========================
# DONE with Event: continuous10
# Time: 0:00:00.004129
# ========================
#
# =============
# metadata mode
# =============
# initializing files and directories...DONE
# check the availability: RESIF
#
# availability for event: 11/31 ---> DONE
# Time for checking the availability: 0:00:00.908903
# [INFO] requested data sources:
# RESIF
#
# RESIF -- event: /Users/mary/Documents/Courses_and_Workshops/IASPEI_Lisbon_SEP'25/codes/data_rhum_rum_continuous/continuous11
#
# ========================
# DONE with Event: continuous11
# Time: 0:00:00.003410
# ========================
#
# =============
# metadata mode
# =============
# initializing files and directories...DONE
# check the availability: RESIF
#
# availability for event: 12/31 ---> DONE
# Time for checking the availability: 0:00:01.279730
# [INFO] requested data sources:
# RESIF
#
# RESIF -- event: /Users/mary/Documents/Courses_and_Workshops/IASPEI_Lisbon_SEP'25/codes/data_rhum_rum_continuous/continuous12
#
# ========================
# DONE with Event: continuous12
# Time: 0:00:00.003062
# ========================
#
# =============
# metadata mode
# =============
# initializing files and directories...DONE
# check the availability: RESIF
#
# availability for event: 13/31 ---> DONE
# Time for checking the availability: 0:00:00.978149
# [INFO] requested data sources:
# RESIF
#
# RESIF -- event: /Users/mary/Documents/Courses_and_Workshops/IASPEI_Lisbon_SEP'25/codes/data_rhum_rum_continuous/continuous13
#
# ========================
# DONE with Event: continuous13
# Time: 0:00:00.002469
# ========================
#
# =============
# metadata mode
# =============
# initializing files and directories...DONE
# check the availability: RESIF
#
# availability for event: 14/31 ---> DONE
# Time for checking the availability: 0:00:01.015440
# [INFO] requested data sources:
# RESIF
#
# RESIF -- event: /Users/mary/Documents/Courses_and_Workshops/IASPEI_Lisbon_SEP'25/codes/data_rhum_rum_continuous/continuous14
#
# ========================
# DONE with Event: continuous14
# Time: 0:00:00.003055
# ========================
#
# =============
# metadata mode
# =============
# initializing files and directories...DONE
# check the availability: RESIF
#
# availability for event: 15/31 ---> DONE
# Time for checking the availability: 0:00:00.915099
# [INFO] requested data sources:
# RESIF
#
# RESIF -- event: /Users/mary/Documents/Courses_and_Workshops/IASPEI_Lisbon_SEP'25/codes/data_rhum_rum_continuous/continuous15
#
# ========================
# DONE with Event: continuous15
# Time: 0:00:00.003167
# ========================
#
# =============
# metadata mode
# =============
# initializing files and directories...DONE
# check the availability: RESIF
#
# availability for event: 16/31 ---> DONE
# Time for checking the availability: 0:00:00.958134
# [INFO] requested data sources:
# RESIF
#
# RESIF -- event: /Users/mary/Documents/Courses_and_Workshops/IASPEI_Lisbon_SEP'25/codes/data_rhum_rum_continuous/continuous16
#
# ========================
# DONE with Event: continuous16
# Time: 0:00:00.003557
# ========================
#
# =============
# metadata mode
# =============
# initializing files and directories...DONE
# check the availability: RESIF
#
# availability for event: 17/31 ---> DONE
# Time for checking the availability: 0:00:00.874160
# [INFO] requested data sources:
# RESIF
#
# RESIF -- event: /Users/mary/Documents/Courses_and_Workshops/IASPEI_Lisbon_SEP'25/codes/data_rhum_rum_continuous/continuous17
#
# ========================
# DONE with Event: continuous17
# Time: 0:00:00.003145
# ========================
#
# =============
# metadata mode
# =============
# initializing files and directories...DONE
# check the availability: RESIF
#
# availability for event: 18/31 ---> DONE
# Time for checking the availability: 0:00:00.863037
# [INFO] requested data sources:
# RESIF
#
# RESIF -- event: /Users/mary/Documents/Courses_and_Workshops/IASPEI_Lisbon_SEP'25/codes/data_rhum_rum_continuous/continuous18
#
# ========================
# DONE with Event: continuous18
# Time: 0:00:00.002894
# ========================
#
# =============
# metadata mode
# =============
# initializing files and directories...DONE
# check the availability: RESIF
#
# availability for event: 19/31 ---> DONE
# Time for checking the availability: 0:00:00.967680
# [INFO] requested data sources:
# RESIF
#
# RESIF -- event: /Users/mary/Documents/Courses_and_Workshops/IASPEI_Lisbon_SEP'25/codes/data_rhum_rum_continuous/continuous19
#
# ========================
# DONE with Event: continuous19
# Time: 0:00:00.003138
# ========================
#
# =============
# metadata mode
# =============
# initializing files and directories...DONE
# check the availability: RESIF
#
# availability for event: 20/31 ---> DONE
# Time for checking the availability: 0:00:00.919927
# [INFO] requested data sources:
# RESIF
#
# RESIF -- event: /Users/mary/Documents/Courses_and_Workshops/IASPEI_Lisbon_SEP'25/codes/data_rhum_rum_continuous/continuous20
#
# ========================
# DONE with Event: continuous20
# Time: 0:00:00.002745
# ========================
#
# =============
# metadata mode
# =============
# initializing files and directories...DONE
# check the availability: RESIF
#
# availability for event: 21/31 ---> DONE
# Time for checking the availability: 0:00:00.944862
# [INFO] requested data sources:
# RESIF
#
# RESIF -- event: /Users/mary/Documents/Courses_and_Workshops/IASPEI_Lisbon_SEP'25/codes/data_rhum_rum_continuous/continuous21
#
# ========================
# DONE with Event: continuous21
# Time: 0:00:00.002987
# ========================
#
# =============
# metadata mode
# =============
# initializing files and directories...DONE
# check the availability: RESIF
#
# availability for event: 22/31 ---> DONE
# Time for checking the availability: 0:00:00.918364
# [INFO] requested data sources:
# RESIF
#
# RESIF -- event: /Users/mary/Documents/Courses_and_Workshops/IASPEI_Lisbon_SEP'25/codes/data_rhum_rum_continuous/continuous22
#
# ========================
# DONE with Event: continuous22
# Time: 0:00:00.003438
# ========================
#
# =============
# metadata mode
# =============
# initializing files and directories...DONE
# check the availability: RESIF
#
# availability for event: 23/31 ---> DONE
# Time for checking the availability: 0:00:00.911162
# [INFO] requested data sources:
# RESIF
#
# RESIF -- event: /Users/mary/Documents/Courses_and_Workshops/IASPEI_Lisbon_SEP'25/codes/data_rhum_rum_continuous/continuous23
#
# ========================
# DONE with Event: continuous23
# Time: 0:00:00.002786
# ========================
#
# =============
# metadata mode
# =============
# initializing files and directories...DONE
# check the availability: RESIF
#
# availability for event: 24/31 ---> DONE
# Time for checking the availability: 0:00:00.860142
# [INFO] requested data sources:
# RESIF
#
# RESIF -- event: /Users/mary/Documents/Courses_and_Workshops/IASPEI_Lisbon_SEP'25/codes/data_rhum_rum_continuous/continuous24
#
# ========================
# DONE with Event: continuous24
# Time: 0:00:00.002516
# ========================
#
# =============
# metadata mode
# =============
# initializing files and directories...DONE
# check the availability: RESIF
#
# availability for event: 25/31 ---> DONE
# Time for checking the availability: 0:00:00.909240
# [INFO] requested data sources:
# RESIF
#
# RESIF -- event: /Users/mary/Documents/Courses_and_Workshops/IASPEI_Lisbon_SEP'25/codes/data_rhum_rum_continuous/continuous25
#
# ========================
# DONE with Event: continuous25
# Time: 0:00:00.003065
# ========================
#
# =============
# metadata mode
# =============
# initializing files and directories...DONE
# check the availability: RESIF
#
# availability for event: 26/31 ---> DONE
# Time for checking the availability: 0:00:00.959861
# [INFO] requested data sources:
# RESIF
#
# RESIF -- event: /Users/mary/Documents/Courses_and_Workshops/IASPEI_Lisbon_SEP'25/codes/data_rhum_rum_continuous/continuous26
#
# ========================
# DONE with Event: continuous26
# Time: 0:00:00.002943
# ========================
#
# =============
# metadata mode
# =============
# initializing files and directories...DONE
# check the availability: RESIF
#
# availability for event: 27/31 ---> DONE
# Time for checking the availability: 0:00:00.809494
# [INFO] requested data sources:
# RESIF
#
# RESIF -- event: /Users/mary/Documents/Courses_and_Workshops/IASPEI_Lisbon_SEP'25/codes/data_rhum_rum_continuous/continuous27
#
# ========================
# DONE with Event: continuous27
# Time: 0:00:00.003400
# ========================
#
# =============
# metadata mode
# =============
# initializing files and directories...DONE
# check the availability: RESIF
#
# availability for event: 28/31 ---> DONE
# Time for checking the availability: 0:00:00.854168
# [INFO] requested data sources:
# RESIF
#
# RESIF -- event: /Users/mary/Documents/Courses_and_Workshops/IASPEI_Lisbon_SEP'25/codes/data_rhum_rum_continuous/continuous28
#
# ========================
# DONE with Event: continuous28
# Time: 0:00:00.002589
# ========================
#
# =============
# metadata mode
# =============
# initializing files and directories...DONE
# check the availability: RESIF
#
# availability for event: 29/31 ---> DONE
# Time for checking the availability: 0:00:01.450944
# [INFO] requested data sources:
# RESIF
#
# RESIF -- event: /Users/mary/Documents/Courses_and_Workshops/IASPEI_Lisbon_SEP'25/codes/data_rhum_rum_continuous/continuous29
#
# ========================
# DONE with Event: continuous29
# Time: 0:00:00.002740
# ========================
#
# =============
# metadata mode
# =============
# initializing files and directories...DONE
# check the availability: RESIF
#
# availability for event: 30/31 ---> DONE
# Time for checking the availability: 0:00:00.969558
# [INFO] requested data sources:
# RESIF
#
# RESIF -- event: /Users/mary/Documents/Courses_and_Workshops/IASPEI_Lisbon_SEP'25/codes/data_rhum_rum_continuous/continuous30
#
# ========================
# DONE with Event: continuous30
# Time: 0:00:00.003319
# ========================
#
# =============
# metadata mode
# =============
# initializing files and directories...DONE
# check the availability: RESIF
#
# availability for event: 31/31 ---> DONE
# Time for checking the availability: 0:00:00.908213
# [INFO] requested data sources:
# RESIF
#
# RESIF -- event: /Users/mary/Documents/Courses_and_Workshops/IASPEI_Lisbon_SEP'25/codes/data_rhum_rum_continuous/continuous31
#
# ========================
# DONE with Event: continuous31
# Time: 0:00:00.003721
# ========================
# [LOCAL] Path:
# /Users/mary/Documents/Courses_and_Workshops/IASPEI_Lisbon_SEP'25/codes/data_rhum_rum_continuous/continuous01
# [INFO] update station_event file...
# [1/5] start processing: YV.RR11.00.BHZ
# [2/5] start processing: YV.RR20.00.BHZ
# [3/5] start processing: YV.RR26.00.BHZ
# [4/5] start processing: YV.RR30.00.BHZ
# [5/5] start processing: YV.RR40.00.BHZ
# [LOCAL] Path:
# /Users/mary/Documents/Courses_and_Workshops/IASPEI_Lisbon_SEP'25/codes/data_rhum_rum_continuous/continuous02
# [INFO] update station_event file...
# [1/5] start processing: YV.RR11.00.BHZ
# [2/5] start processing: YV.RR20.00.BHZ
# [3/5] start processing: YV.RR26.00.BHZ
# [4/5] start processing: YV.RR30.00.BHZ
# [5/5] start processing: YV.RR40.00.BHZ
# [LOCAL] Path:
# /Users/mary/Documents/Courses_and_Workshops/IASPEI_Lisbon_SEP'25/codes/data_rhum_rum_continuous/continuous03
# [INFO] update station_event file...
# [1/2] start processing: YV.RR30.00.BHZ
# [2/2] start processing: YV.RR40.00.BHZ
# [LOCAL] Path:
# /Users/mary/Documents/Courses_and_Workshops/IASPEI_Lisbon_SEP'25/codes/data_rhum_rum_continuous/continuous04
# [INFO] update station_event file...
# [1/2] start processing: YV.RR30.00.BHZ
# [2/2] start processing: YV.RR40.00.BHZ
# [LOCAL] Path:
# /Users/mary/Documents/Courses_and_Workshops/IASPEI_Lisbon_SEP'25/codes/data_rhum_rum_continuous/continuous05
# [INFO] update station_event file...
# [1/2] start processing: YV.RR30.00.BHZ
# [2/2] start processing: YV.RR40.00.BHZ
# [LOCAL] Path:
# /Users/mary/Documents/Courses_and_Workshops/IASPEI_Lisbon_SEP'25/codes/data_rhum_rum_continuous/continuous06
# [INFO] update station_event file...
# [1/1] start processing: YV.RR40.00.BHZ
# [LOCAL] Path:
# /Users/mary/Documents/Courses_and_Workshops/IASPEI_Lisbon_SEP'25/codes/data_rhum_rum_continuous/continuous07
# [INFO] update station_event file...
# [1/1] start processing: YV.RR40.00.BHZ
# [LOCAL] Path:
# /Users/mary/Documents/Courses_and_Workshops/IASPEI_Lisbon_SEP'25/codes/data_rhum_rum_continuous/continuous08
# [INFO] update station_event file...
# [1/1] start processing: YV.RR40.00.BHZ
# [LOCAL] Path:
# /Users/mary/Documents/Courses_and_Workshops/IASPEI_Lisbon_SEP'25/codes/data_rhum_rum_continuous/continuous09
# [INFO] update station_event file...
# [1/1] start processing: YV.RR40.00.BHZ
# [LOCAL] Path:
# /Users/mary/Documents/Courses_and_Workshops/IASPEI_Lisbon_SEP'25/codes/data_rhum_rum_continuous/continuous10
# [INFO] update station_event file...
# [1/1] start processing: YV.RR40.00.BHZ
# [LOCAL] Path:
# /Users/mary/Documents/Courses_and_Workshops/IASPEI_Lisbon_SEP'25/codes/data_rhum_rum_continuous/continuous11
# [INFO] update station_event file...
# [1/1] start processing: YV.RR40.00.BHZ
# [LOCAL] Path:
# /Users/mary/Documents/Courses_and_Workshops/IASPEI_Lisbon_SEP'25/codes/data_rhum_rum_continuous/continuous12
# [INFO] update station_event file...
# [1/1] start processing: YV.RR40.00.BHZ
# [LOCAL] Path:
# /Users/mary/Documents/Courses_and_Workshops/IASPEI_Lisbon_SEP'25/codes/data_rhum_rum_continuous/continuous13
# [INFO] update station_event file...
# [1/1] start processing: YV.RR40.00.BHZ
# [LOCAL] Path:
# /Users/mary/Documents/Courses_and_Workshops/IASPEI_Lisbon_SEP'25/codes/data_rhum_rum_continuous/continuous14
# [INFO] update station_event file...
# [1/1] start processing: YV.RR40.00.BHZ
# [LOCAL] Path:
# /Users/mary/Documents/Courses_and_Workshops/IASPEI_Lisbon_SEP'25/codes/data_rhum_rum_continuous/continuous15
# [INFO] update station_event file...
# [1/1] start processing: YV.RR40.00.BHZ
# [LOCAL] Path:
# /Users/mary/Documents/Courses_and_Workshops/IASPEI_Lisbon_SEP'25/codes/data_rhum_rum_continuous/continuous16
# [INFO] update station_event file...
# [1/1] start processing: YV.RR40.00.BHZ
# [LOCAL] Path:
# /Users/mary/Documents/Courses_and_Workshops/IASPEI_Lisbon_SEP'25/codes/data_rhum_rum_continuous/continuous17
# [INFO] update station_event file...
# [1/1] start processing: YV.RR40.00.BHZ
# [LOCAL] Path:
# /Users/mary/Documents/Courses_and_Workshops/IASPEI_Lisbon_SEP'25/codes/data_rhum_rum_continuous/continuous18
# [INFO] update station_event file...
# [1/1] start processing: YV.RR40.00.BHZ
# [LOCAL] Path:
# /Users/mary/Documents/Courses_and_Workshops/IASPEI_Lisbon_SEP'25/codes/data_rhum_rum_continuous/continuous19
# [INFO] update station_event file...
# [1/1] start processing: YV.RR40.00.BHZ
# [LOCAL] Path:
# /Users/mary/Documents/Courses_and_Workshops/IASPEI_Lisbon_SEP'25/codes/data_rhum_rum_continuous/continuous20
# [INFO] update station_event file...
# [1/1] start processing: YV.RR40.00.BHZ
# [LOCAL] Path:
# /Users/mary/Documents/Courses_and_Workshops/IASPEI_Lisbon_SEP'25/codes/data_rhum_rum_continuous/continuous21
# [INFO] update station_event file...
# [1/1] start processing: YV.RR40.00.BHZ
# [LOCAL] Path:
# /Users/mary/Documents/Courses_and_Workshops/IASPEI_Lisbon_SEP'25/codes/data_rhum_rum_continuous/continuous22
# [INFO] update station_event file...
# [1/1] start processing: YV.RR40.00.BHZ
# [LOCAL] Path:
# /Users/mary/Documents/Courses_and_Workshops/IASPEI_Lisbon_SEP'25/codes/data_rhum_rum_continuous/continuous23
# [INFO] update station_event file...
# [1/1] start processing: YV.RR40.00.BHZ
# [LOCAL] Path:
# /Users/mary/Documents/Courses_and_Workshops/IASPEI_Lisbon_SEP'25/codes/data_rhum_rum_continuous/continuous24
# [INFO] update station_event file...
# [1/1] start processing: YV.RR40.00.BHZ
# [LOCAL] Path:
# /Users/mary/Documents/Courses_and_Workshops/IASPEI_Lisbon_SEP'25/codes/data_rhum_rum_continuous/continuous25
# [INFO] update station_event file...
# [1/1] start processing: YV.RR40.00.BHZ
# [LOCAL] Path:
# /Users/mary/Documents/Courses_and_Workshops/IASPEI_Lisbon_SEP'25/codes/data_rhum_rum_continuous/continuous26
# [INFO] update station_event file...
# [1/1] start processing: YV.RR40.00.BHZ
# [LOCAL] Path:
# /Users/mary/Documents/Courses_and_Workshops/IASPEI_Lisbon_SEP'25/codes/data_rhum_rum_continuous/continuous27
# [INFO] update station_event file...
# [1/1] start processing: YV.RR40.00.BHZ
# [LOCAL] Path:
# /Users/mary/Documents/Courses_and_Workshops/IASPEI_Lisbon_SEP'25/codes/data_rhum_rum_continuous/continuous28
# [INFO] update station_event file...
# [1/1] start processing: YV.RR40.00.BHZ
# [LOCAL] Path:
# /Users/mary/Documents/Courses_and_Workshops/IASPEI_Lisbon_SEP'25/codes/data_rhum_rum_continuous/continuous29
# [INFO] update station_event file...
# [1/1] start processing: YV.RR40.00.BHZ
# [LOCAL] Path:
# /Users/mary/Documents/Courses_and_Workshops/IASPEI_Lisbon_SEP'25/codes/data_rhum_rum_continuous/continuous30
# [INFO] update station_event file...
# [1/1] start processing: YV.RR40.00.BHZ
# [LOCAL] Path:
# /Users/mary/Documents/Courses_and_Workshops/IASPEI_Lisbon_SEP'25/codes/data_rhum_rum_continuous/continuous31
# [INFO] update station_event file...
# [1/1] start processing: YV.RR40.00.BHZ
#
#
# ==================================================
# obspyDMT main program has finished!
#
# /Users/mary/Documents/Courses_and_Workshops/IASPEI_Lisbon_SEP'25/codes/data_rhum_rum_continuous
# * Total time of execution: 0:00:31 (h:m:s)
# ==================================================

# %% [markdown]
# Now we need to read each day file and add it to the obspy internal PPSD function.

# %% [markdown]
# ### Example one day file

# %%
st = read(
    "/Users/mary/Documents/Courses_and_Workshops/IASPEI_Lisbon_SEP'25/codes/data_rhum_rum_continuous/continuous01/raw/YV.RR40.00.BHZ"
)
inv = read_inventory(
    "/Users/mary/Documents/Courses_and_Workshops/IASPEI_Lisbon_SEP'25/codes/data_rhum_rum_continuous/continuous01/resp/STXML.YV.RR40.00.BHZ"
)

ppsd = PPSD(st[0].stats, metadata=inv)
ppsd.add(st[0])

ppsd.plot(cmap=pqlx)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### Example multiple day files

# %%
# locate all the mseed files
mseed_paths = glob.glob("data_rhum_rum_continuous/continuous*/raw/*40*.BHZ")

for i, mseed_path in enumerate(mseed_paths):

    inv = read_inventory(
        os.path.join(mseed_path.split("/raw")[0], "resp", "STXML.YV.RR40.00.BHZ")
    )

    st = read(mseed_path)

    if i ==0:
        ppsd = PPSD(st[0].stats, metadata=inv)
        ppsd.add(st)
    else:
        st = read(mseed_path)
        ppsd.add(st)

# %%
ppsd.plot(cmap=pqlx)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### Some useful extra commands

# %%
print(ppsd)
print(ppsd.times_processed[:2]) #check what time ranges are represented in the ppsd estimate
print("Number of psd segments:", len(ppsd.times_processed))


ppsd.plot(cumulative=True,cmap=pqlx) #cumulative version of the histogram

ppsd.plot_temporal(period=[0.1, 1.0, 10]) #The central period closest to the specified period is selected

ppsd.plot_spectrogram() #Plot the spectrogram for the whole duration
# Out:
# <obspy.signal.spectral_estimation.PPSD object at 0x141173bb0>
# [UTCDateTime(2013, 1, 1, 0, 0, 0, 3800), UTCDateTime(2013, 1, 1, 0, 30, 0, 3800)]
# Number of psd segments: 1457
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# You can also save the ppsd file as .npz file to load later
ppsd.save("ppsd_RR40.npz")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 2
#       1 # You can also save the ppsd file as .npz file to load later
# ----> 2 ppsd.save("ppsd_RR40.npz")
#
# AttributeError: 'PPSD' object has no attribute 'save'

# %% [markdown]
# ## Further exercise
#
# - Load the saved .npz file and try to plot the PPSD plot again. Hint: https://docs.obspy.org/packages/autogen/obspy.signal.spectral_estimation.PPSD.load_npz.html
# - Download more data and add more days to the PPSD. Does it change?
# - Can you plot time dependent PPSD (spring, summer, autumn, winter)? Hint: https://docs.obspy.org/packages/autogen/obspy.signal.spectral_estimation.PPSD.times_processed.html
